# %%
# !pip install Selenium
# !apt-get upadate
# !apt install chromium-chromedriver
# !cp/ usr/bin/chormium-browser/chromedriver /usr/bin
# Out:
# ...
# 'apt-get'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'apt'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'cp'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import warnings
from selenium.webdriver.common.by import By
warnings.filterwarnings('ignore')
url = 'https://naver.com'
path = r'C:\Users\ejrgu\OneDrive\바탕 화면\git hub\cakd7\1차 프로젝트_웹_API_0902-0926\크롤링 및 머신런닝\chromedriver_win32\chromedriver.exe'  #이걸 실행시켜서 크롬을 실행
driver = webdriver.Chrome(path)
driver.get(url)

# %%
import time

# %%
options = webdriver.ChromeOptions()
options.add_argument('window_size=1920,1080')
driver = webdriver.Chrome(path, options=options)
driver.get(url='https://st.scrdairy.com/')

# element = driver.find_element(By.CLASS_NAME,'ng-pristine ng-invalid ng-touched')
# element.click()

username = '202002-seou@yhdairy.co.kr'
password = 'starT002'
farmId ='AP5139200'
element = driver.find_element(By.XPATH,'/html/body/app-root/login/div/form/div[1]/div[3]/input')
element.send_keys(username)
element = driver.find_element(By.XPATH,'/html/body/app-root/login/div/form/div[1]/div[5]/input')
element.send_keys(password)
element = driver.find_element(By.XPATH,'/html/body/app-root/login/div/form/div[1]/div[7]/input')
element.send_keys(farmId)
element = driver.find_element(By.CLASS_NAME,'login-btn').click()

time.sleep(12)
element = driver.find_element(By.XPATH,'/html/body/app-root/logged-in-layout/left-menu/div/div[2]').click()
element = driver.find_element(By.XPATH,'/html/body/app-root/logged-in-layout/left-menu/nav/menu-item-manage/a/span[1]/i').click()
time.sleep(5)
element = driver.find_element(By.XPATH,'/html/body/app-root/logged-in-layout/div/div/manage/div/div[2]/manage-animals/div/div/manage-active-animals/report-grid/div/div/ngx-datatable/div/datatable-body/datatable-selection/datatable-scroller/datatable-row-wrapper[1]/datatable-body-row/div[2]/datatable-body-cell[1]/div/div').click()
time.sleep(5)
# 옆으로 넘어가기 클릭
element = driver.find_element(By.XPATH,'/html/body/app-root/logged-in-layout/card-popup/div/div[3]/div/div[2]/span[3]')

cow_datas = []
cow_datas.append(driver.find_element(By.XPATH,'/html/body/app-root/logged-in-layout/card-popup/div/div[1]/div[2]/animal-card/div/div/animal-card-events').text)

for _ in range(347):
    element.click()
    time.sleep(5)
    cow_datas.append(driver.find_element(By.XPATH,'/html/body/app-root/logged-in-layout/card-popup/div/div[1]/div[2]/animal-card/div/div/animal-card-events').text)

# %%
cow_df=cow_datas.copy()
cow_df
# Out:
# ['이벤트 기록\n추가 작업\n날짜\n이벤트 이름\n출생 후 일수/연령\n설명\n2022.09.01. 오후 4:44\nFlex 태그 제거\n195\n제거된 태그: \n10057870\n2022.09.01. 오후 4:44\n양성\n195\n결과: \n양성\n2022.08.11. 오후 8:36\n통증 / 스트레스\n174\n지속 시간: \n16:30\n2022.08.08. 오전 5:59\n시스템 발정\n171\n발정 지수: \n94.53\n2022.06.28. 오전 11:59\n시스템 건강\n130\n건강 지수: \n79\n2022.06.04. 오전 6:59\n시스템 발정\n106\n발정 지수: \n46.75\n2022.04.27. 오전 5:59\n시스템 발정\n68\n발정 지수: \n97.46\n2022.04.01. 오후 6:14\n수정\n42\n수정 횟수: \n1\n2022.04.01. 오전 5:59\n시스템 발정\n42\n발정 지수: \n95.5\n2022.03.11. 오전 12:01\n통증 / 스트레스\n21\n지속 시간: \n21:00\n2022.03.09. 오후 6:58\nFlex 태그 할당\n19\n새 태그: \n10057870\n2022.02.18. 오전 11:47\n분만\n0\n신규 분만 수: \n1',
# ...

# %%
import pandas as pd
cow_df = pd.DataFrame(cow_df)

# %%
display(cow_df.loc[0])
# Out:
# 0    이벤트 기록\n추가 작업\n날짜\n이벤트 이름\n출생 후 일수/연령\n설명\n202...
# Name: 0, dtype: object

# %%
import pickle
with open('cow_datas.pickle','wb') as fw:
    pickle.dump(cow_datas, fw)
