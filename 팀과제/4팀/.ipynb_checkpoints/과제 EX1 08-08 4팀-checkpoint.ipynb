# %% [markdown]
# ### Q63. 네이버 검색에서 관심 주제와 기사 수를 입력하면 그만큼 출력하는 크롤링 프로그램을 작성하여 다음 사항을 수행하세요.
#
# - 기사 제목과 링크를 데이터프레임으로 가져온 후 본문 내용에서 한글 단어만 출력하여 형태소 분석
# - 최근 국내 'AI'와 관련하여 가장 많이 언급되는 단어에 대한 빈도분석 및 시각화
# - AI 분야에서의 유의할 만한 트랜드 정보 및 인사이트 도출

# %%
from urllib.parse import quote
import urllib
from bs4 import BeautifulSoup
import re
import pandas as pd
from collections import Counter
from matplotlib import rc
import seaborn as sns

rc('font',family='Malgun Gothic') # 한글 폰트 설정
plt.rcParams['axes.unicode_minus'] = False # 마이너스 부호 출력 설정

# %%
from urllib.parse import quote
import urllib
from bs4 import BeautifulSoup
import re
import pandas as pd
df_1 = pd.DataFrame(columns=['text'])


query = quote(input('검색 할 내용을 입력하세요.'))
cnt = int(input('원하는 기사의 수를 입력하세요.'))
start = 1
ind = 0
url_link =[]
text_all =[]
tatile =[]
print(f'='*100+'\n현재 URL 수집 중 입니다.')
while cnt > len(url_link):
    url = f'https://search.naver.com/search.naver?where=news&query={query}&start={str(start)}'
    html = urllib.request.urlopen(url)
    bs = BeautifulSoup(html,'lxml')
    mask = bs.select('.list_news > li > div > div > div > div > a.info')
    for x in mask:
        if (cnt >len(url_link)) & (x.get_text() == '네이버뉴스'):
            url_link.append(x['href'])
    start += 10
    
print(f'URL 수집 종료.')
print(f'='*100+'\n현재 본문 수집 중 입니다.')
for url in url_link:
    response = urllib.request.urlopen(url)
    soup = BeautifulSoup(response, 'lxml')
    text = soup.select_one('#dic_area')
    if text == None:
        pass
    else:
        text_all.append(text.text)
print(f'='*100+'\n본문 수집 종료.')
df_1['text'] = text_all
df_1
# Out:
# 검색 할 내용을 입력하세요.전력
# 원하는 기사의 수를 입력하세요.100
# ====================================================================================================
# 현재 URL 수집 중 입니다.
# URL 수집 종료.
# ====================================================================================================
# 현재 본문 수집 중 입니다.
# ====================================================================================================
# 본문 수집 종료.
#                                                  text
# 0   \n기사내용 요약최대 전력 수요 상한 전망 9만5700㎿전력 수급 경보 '준비' 발...
# 1   \n\n\n\n\n/사진제공 = 총리실한덕수 국무총리가 중부지방 집중호우로 인한 피...
# 2   \n열대야·무더위 지속… 최대전력 급증 우려전국적으로 폭염과 열대야가 지속되는 가운...
# 3   \n\n\n\n\n전력거래소가 8월 둘째 주 전력수요는 88.0~91.0GW, 예비...
# 4   \n도민 체감, 소상공인 지원, 전통시장 활성화 등 3개 분야 44개 사업 추진\n...
# ..                                                ...
# 85  \n\n\n\n\n다음주 전력수요가 늘어날 전망이다. 사진은 서울 한 다세대주택에 ...
# 86  \n\n\n\n\n1일 전력거래소에 따르면 7월 월평균 최대전력(30일 기준)은 지...
# 87  \n\t\t\t[이데일리 강경래 기자] 알에프세미(096610)가 예스파워테크닉스와...
# 88  \n\n\n\n\n[서울=뉴시스] 김진아 기자 = 다음주가 올여름 전력 수급 최대 ...
# 89  \n기사내용 요약7월 SMP 151.85원…전월比 상승 전환국제유가 오르며 LNG ...
#
# [90 rows x 1 columns]

# %%
from collections import Counter
from konlpy.tag import Okt
import matplotlib.pyplot as plt
from wordcloud import WordCloud
stopword = ['인공','지능','개발','활용','통해','이번','분야'
            '위해','진행','예정','기자','평가','지난','현재',
            '라며','확인','방식','실제','이용',
            '뉴스','이미지','의미','출시','발생','내용','발표','상품','지난해',
            '시작','때문','최초','단계','가지','스케','통한','하나',
            '가장','더욱','직접','뉴시스','모든','추천','광고','또한',
            '실시간','기사','모두','기간','홈페이지','검색','누구','우선',
            '연합뉴스','앞서','그동안','이데일리','지난달','대부분','여기',
            '작년','번역','미디어아트','업데이트','파이낸셜뉴스','페이지',
            '무엇','이름']

noun =[]
for d in df_1.text:
    morphs = Okt().pos(d)
    for j,k in morphs:
        if(len(j) > 1 ) & (k == 'Noun'):
            noun.append(j)
wordsbody = dict(Counter(noun).most_common())
for i in stopword:
    if i in wordsbody:
        wordsbody.pop(i)

print('기사 본문 WordCloud')
wc = WordCloud(font_path='../../m2_분석라이브러리활용/malgun.ttf',background_color="white", max_font_size=60)
cloud = wc.generate_from_frequencies(wordsbody)
plt.figure(figsize=(10, 8))
plt.axis('off')
plt.imshow(cloud)
plt.show()

# %%
import numpy as np
se_wc = pd.Series(wordsbody)
df_wc = pd.DataFrame(se_wc,columns=['cnt'])
df_wc.reset_index(inplace=True)
df_wc

# %%
# df_wc.to_csv('wc.csv')
# df_1.to_csv('df_1.csv')
df_wc = pd.read_csv('df_wc')
df_1 = pd.read_csv('df_1.csv')
df_1
# Out:
#      Unnamed: 0                                               text
# 0             0  \n\n\n\n\n농정원, 스마트농업 AI 경진대회[농림수산식품교육문화정보원 제공....
# 1             1  \n스타트업 '지속가능발전소'와 협업ESG 리스크 모니터링 서비스 제공중견기업 관련...
# 2             2  \n기사내용 요약병원 업무 자동화에 클로바 AI콜 솔루션 도입AI 관련 연구과제 발...
# 3             3  \n\n\n\n\n이미희 KT C레벨컨설팅본부장(왼쪽)과 전준수 NIPA 글로벌성장...
# 4             4  \n\n\n\n\n대구 영진전문대 AI융합기계계열 이우영·안진영·신형식·김찬혁·임재...
# ..          ...                                                ...
# 982         982  \n\n\n\n\n한국과학기술정보연구원(KISTI·원장 김재수)이 주관하고, 과학기...
# 983         983  \n\n\n\n\n문형남 대한경영학회장·대한민국ESG메타버스포럼 의장인공지능(AI)...
# 984         984  \n\n\n\n\n\n\n\n\nSK텔레콤이 인공지능(AI) 기반 음성 안내 플랫폼...
# 985         985  \n"전혀 근거 없는 주장…고용-보안지침 위반"구글이 개발 중인 대화형 인공지능(A...
# 986         986  \n\n\n\n\n/사진=한국인터넷진흥원(KISA) 제공정부의 사이버보안 인공지능(...
#
# [987 rows x 2 columns]

# %%
from collections import Counter
from konlpy.tag import Okt
import matplotlib.pyplot as plt
from wordcloud import WordCloud
stopword = ['인공','지능','개발','활용','통해','이번','분야','제공','설명',
            '위해','진행','예정','기자','평가','지난','현재',
            '라며','확인','방식','실제','이용',
            '뉴스','이미지','의미','출시','발생','내용','발표','상품','지난해',
            '시작','때문','최초','단계','가지','스케','통한','하나',
            '가장','더욱','직접','뉴시스','모든','추천','광고','또한',
            '실시간','기사','모두','기간','홈페이지','검색','누구','우선',
            '연합뉴스','앞서','그동안','이데일리','지난달','대부분','여기',
            '작년','번역','미디어아트','업데이트','파이낸셜뉴스','페이지',
            '무엇','이름']

noun =[]
for d in df_1.text:
    morphs = Okt().pos(d)
    for j,k in morphs:
        if(len(j) > 1 ) & (k == 'Noun'):
            noun.append(j)
wordsbody = dict(Counter(noun).most_common())
for i in stopword:
    if i in wordsbody:
        wordsbody.pop(i)

print('기사 본문 WordCloud')
wc = WordCloud(font_path='../../m2_분석라이브러리활용/malgun.ttf',background_color="white", max_font_size=60)
cloud = wc.generate_from_frequencies(wordsbody)
plt.figure(figsize=(10, 8))
plt.axis('off')
plt.imshow(cloud)
plt.show()
# Out:
# 기사 본문 WordCloud

# %%
df5 = pd.DataFrame(list(wordsbody.items()),
                   columns=['index', 'number'])
df5.head(15)
# Out:
#    index  number
# 0     기술    2394
# 1    데이터    1680
# 2    서비스    1533
# 3     기업    1200
# 4     기반    1104
# 5     사업    1072
# 6    솔루션     961
# 7     의료     931
# 8     금융     898
# 9    시스템     860
# 10    연구     827
# 11    교육     812
# 12    분석     714
# 13    학습     712
# 14    산업     690

# %%
sns.barplot(x='index',y='number',data=df5.iloc[:][0:15],orient='v',)
# Out:
# <AxesSubplot:xlabel='index', ylabel='number'>
