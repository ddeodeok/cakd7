# %%
import pandas as pd
df = pd.read_csv('./상권_업종별_남녀비율.csv',encoding='utf-8')

# %%
df
# Out:
#      Unnamed: 0 상권_구분_코드_명   서비스_업종_코드_명       비율 방식  남성 > 여성 비율
# 0           154       관광특구       호프-간이주점  남성 > 여성 비율         0.0
# 1           224       전통시장  자전거 및 기타운송장비  남성 > 여성 비율         0.0
# 2            55       발달상권           편의점  남성 > 여성 비율         0.0
# 3           236       전통시장           PC방  남성 > 여성 비율         0.0
# 4           153       관광특구         자동차수리  남성 > 여성 비율         0.0
# ..          ...        ...           ...         ...         ...
# 247         145       관광특구           고시원  남성 > 여성 비율         1.0
# 248         136       관광특구         외국어학원  남성 > 여성 비율         1.0
# 249         159       관광특구         커피-음료  남성 > 여성 비율         1.0
# 250         178       관광특구        부동산중개업  남성 > 여성 비율         NaN
# 251         161       관광특구  자전거 및 기타운송장비  남성 > 여성 비율         NaN
#
# [252 rows x 5 columns]
