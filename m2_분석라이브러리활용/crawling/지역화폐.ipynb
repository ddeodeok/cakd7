# %%
import os
import sys
import urllib.request


key = "QAo9SA83vv5BBFVrr8g9"
url = "https://openapi.gg.go.kr/RegionMnyPublctUse"

# %%
import pandas as pd
df_1 = pd.read_csv("지역화폐발행및이용현황.csv",encoding='cp949')
df_1
# Out:
#       시군명     기준년월  월별카드발행수량(건)  월별카드충전액(천원)  월별카드사용액(천원)  월별모바일상품권이용등록자수(명)  \
# 0     가평군  2022-06        572.0    2771279.0    2681386.0                NaN
# 1     가평군  2022-05        627.0    2784295.0    2810484.0                NaN
# 2     가평군  2022-04        641.0    2585608.0    2600843.0                NaN
# 3     가평군  2022-03        481.0    2393457.0    2418270.0                NaN
# 4     가평군  2022-02        427.0    2063838.0    1920192.0                NaN
# ...   ...      ...          ...          ...          ...                ...
# 1297  화성시  2019-05      10661.0    4449088.0    1392631.0                NaN
# 1298  화성시  2019-04       4826.0    1476982.0     204210.0                NaN
# 1299  화성시  2019-03          NaN          NaN          NaN                NaN
# 1300  화성시  2019-02          NaN          NaN          NaN                NaN
# 1301  화성시  2019-01          NaN          NaN          NaN                NaN
#
# ...
