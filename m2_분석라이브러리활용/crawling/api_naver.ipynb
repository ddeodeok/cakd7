# %% [markdown]
# ## 네이버 검색 API 서비스

# %% [markdown]
# #### 블로그

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "QAo9SA83vv5BBFVrr8g9"
client_secret = "s7laUToZA7"

query = urllib.parse.quote(input("검색 질의"))
url = "https://openapi.naver.com/v1/search/blog?query=" + query # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 검색 질의 빅데이터
# {
# 	"lastBuildDate":"Thu, 28 Jul 2022 22:29:01 +0900",
# 	"total":1144240,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>빅데이터<\/b>전문가 준비를 위한 체계적인 방법",
# 			"link":"https:\/\/blog.naver.com\/nam8853nam?Redirect=Log&logNo=222802704648",
# 			"description":"그 중에서도 주목해 볼만한 분야가 바로 ‘<b>빅데이터<\/b>’ 라고 생각했어요. 기업이 이익을 창출하기... 이런 점들을 고려했을 때 1) 영업, 2) 컨설팅, 3) 제조 분야 모두 통틀어서 데이터 분석이 정말 중요한 부분을... ",
# 			"bloggername":"율맘 스토리",
# 			"bloggerlink":"https:\/\/blog.naver.com\/nam8853nam",
# 			"postdate":"20220707"
# 		},
# 		{
# 			"title":"<b>빅데이터<\/b>분석기사 실기 준비를 위한 학습루틴",
# 			"link":"https:\/\/blog.naver.com\/parkrapp?Redirect=Log&logNo=222753783578",
# 			"description":"안녕하세요, 오늘은 제가 도전한 <b>빅데이터<\/b>분석기사에 대한 정보를 많은 분과 나누고 싶어 이야기를... <b>빅데이터<\/b>를 이해하고 이를 분석, 수집, 저장 등의 시각화를 수행하는 실무자 역할을 하는 분석기사는... ",
# 			"bloggername":"황금빛 쭈롱월드",
# 			"bloggerlink":"https:\/\/blog.naver.com\/parkrapp",
# 			"postdate":"20220531"
# 		},
# 		{
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
xml = response_body.decode('utf-8')
bs = BeautifulSoup(xml,'lxml')
bs.get_text()
# Out:
# '{\n\t"lastBuildDate":"Thu, 28 Jul 2022 22:29:01 +0900",\n\t"total":1144240,\n\t"start":1,\n\t"display":10,\n\t"items":[\n\t\t{\n\t\t\t"title":"빅데이터<\\/b>전문가 준비를 위한 체계적인 방법",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/nam8853nam?Redirect=Log&logNo=222802704648",\n\t\t\t"description":"그 중에서도 주목해 볼만한 분야가 바로 ‘빅데이터<\\/b>’ 라고 생각했어요. 기업이 이익을 창출하기... 이런 점들을 고려했을 때 1) 영업, 2) 컨설팅, 3) 제조 분야 모두 통틀어서 데이터 분석이 정말 중요한 부분을... ",\n\t\t\t"bloggername":"율맘 스토리",\n\t\t\t"bloggerlink":"https:\\/\\/blog.naver.com\\/nam8853nam",\n\t\t\t"postdate":"20220707"\n\t\t},\n\t\t{\n\t\t\t"title":"빅데이터<\\/b>분석기사 실기 준비를 위한 학습루틴",\n\t\t\t"link":"https:\\/\\/blog.naver.com\\/parkrapp?Redirect=Log&logNo=222753783578",\n\t\t\t"description":"안녕하세요, 오늘은 제가 도전한 빅데이터<\\/b>분석기사에 대한 정보를 많은 분과 나누고 싶어 이야기를... 빅데이터<\\/b>를 이해하고 이를 분석, 수집, 저장 등의 시각화를 수행하는 실무자 역할을 하는 분석기사는... ",\n\t\t\t"bloggername":"황금빛 쭈롱월드",\n\t\t\t"bloggerlink":"https:\\/\\/blog.naver.com\\/parkrapp",\n\t\t\t"postdate":"20220531"\n\t\t},\n\t\t{\n\t\t\t"title":"
# ...

# %% [markdown]
# #### Q.네이버 웹문서에서 빅데이터에 대한 데이터를 가져와서 데이터프레임으로 출력하세요(api가이드 참조)

# %%
import os
import sys
import urllib.request
client_id = "QAo9SA83vv5BBFVrr8g9"
client_secret = "s7laUToZA7"

query = urllib.parse.quote('빅데이터')
url = "https://openapi.naver.com/v1/search/webkr.json?query=" + query+"&display=20&start=1" # json 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 29 Jul 2022 08:55:27 +0900",
# 	"total":38811319,
# 	"start":1,
# 	"display":20,
# 	"items":[
# 		{
# 			"title":"<b>빅 데이터<\/b> 프로세싱 - 나무위키",
# 			"link":"https:\/\/namu.wiki\/w\/%EB%B9%85%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%ED%94%84%EB%A1%9C%EC%84%B8%EC%8B%B1",
# 			"description":"Big data processing 디지털 시대에서 폭증하는 '방대한 양의 <b>데이터<\/b>(big data)'를 관리하고 분석해서 유용한 정보로 사용하는 기술."
# 		},
# 		{
# 			"title":"<b>빅데이터<\/b>란? | 고급 <b>빅데이터<\/b> 분석 | SAP Insights",
# 			"link":"https:\/\/www.sap.com\/korea\/insights\/what-is-big-data.html",
# 			"description":"비즈니스에 대한 360도 통찰을 제공하고 디지털 노이즈 속에 숨은 성장 기회를 찾도록 돕는 <b>빅데이터<\/b> 솔루션을 만나보세요."
# 		},
# 		{
# 			"title":"<b>빅 데이터<\/b>란 무엇입니까? | Oracle 대한민국",
# 			"link":"https:\/\/www.oracle.com\/kr\/big-data\/what-is-big-data\/",
# 			"description":"<b>빅데이터<\/b>는 특히 새로운 <b>데이터<\/b> 소스에서 나온 더 크고 더 복잡한 <b>데이터<\/b> 세트입니다. <b>빅데이터<\/b>의 이점, 과제 및 모범 사례 외에도 정의 및 역사에 대해 알아보세요."
# 		},
# 		{
# ...

# %%
data = response_body.decode('utf-8')
soup = BeautifulSoup(data,'lxml')
data2 = soup.find('title')
print(data2)
# Out:
# None

# %% [markdown]
# #### 과제0728_1
# 웹문서에서 빅데이터에 대한 의미있는 정보로 구성된 데이터프레임을 출력하세요

# %%
import pandas as pd
df = pd.read_json(response_body.decode('utf-8'))
df1 = df.drop(['total','display','start'],axis=1)
# df1['items'].split(',')
titli = []
linkli = []
des = []
for i in range(20):
    for key,value in df1.iloc[i,1].items():
        if key == 'title':
            titli.append(value)
        elif key == 'link':
            linkli.append(value)
        else :
            des.append(value)
df2 = pd.DataFrame(zip(titli,linkli,des),columns=['title','link','description'])
df2.head()
# Out:
#                                               title  \
# 0                          <b>빅 데이터</b> 프로세싱 - 나무위키
# 1  <b>빅데이터</b>란? | 고급 <b>빅데이터</b> 분석 | SAP Insights
# 2                <b>빅 데이터</b>란 무엇입니까? | Oracle 대한민국
# 3  <b>빅데이터</b>(big data) 이해 - 정의, 분석, 기술, 특징, 사례 연구
# 4                                <b>빅데이터</b> - BC카드
#
#                                                 link  \
# 0  https://namu.wiki/w/%EB%B9%85%20%EB%8D%B0%EC%9...
# 1  https://www.sap.com/korea/insights/what-is-big...
# 2  https://www.oracle.com/kr/big-data/what-is-big...
# 3          https://www.redhat.com/ko/topics/big-data
# 4  https://www.bccard.com/card/html/company/kr/bi...
#
#                                          description
# 0  Big data processing 디지털 시대에서 폭증하는 '방대한 양의 <b>데...
# 1  비즈니스에 대한 360도 통찰을 제공하고 디지털 노이즈 속에 숨은 성장 기회를 찾도...
# 2  <b>빅데이터</b>는 특히 새로운 <b>데이터</b> 소스에서 나온 더 크고 더 ...
# 3  <b>빅데이터</b>(big data)란 기존 <b>데이터</b> 프로세싱 방식을 ...
# 4  fnbigdata.com <b>빅데이터</b> 생태계 조성 기반 마련, <b>빅데이...

# %% [markdown]
# #### 지웅님 하신거

# %%
import os
import sys
from urllib  import request
import urllib
client_id = "qG0Cl60JCZycJUBPS057"
client_secret = "GhOb8PFVWJ"
encText = urllib.parse.quote("빅데이터")
url = 'https://openapi.naver.com/v1/search/webkr.json?query='+encText # json 결과
# url = "https://openapi.naver.com/v1/search/webkr.json?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 08 Aug 2022 18:27:12 +0900",
# 	"total":36929588,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"<b>빅 데이터<\/b> 프로세싱 - 나무위키",
# 			"link":"https:\/\/namu.wiki\/w\/%EB%B9%85%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%ED%94%84%EB%A1%9C%EC%84%B8%EC%8B%B1",
# 			"description":"Big data processing 디지털 시대에서 폭증하는 '방대한 양의 <b>데이터<\/b>(big data)'를 관리하고 분석해서 유용한 정보로 사용하는 기술."
# 		},
# 		{
# 			"title":"<b>빅데이터<\/b>란? | 고급 <b>빅데이터<\/b> 분석 | SAP Insights",
# 			"link":"https:\/\/www.sap.com\/korea\/insights\/what-is-big-data.html",
# 			"description":"비즈니스에 대한 360도 통찰을 제공하고 디지털 노이즈 속에 숨은 성장 기회를 찾도록 돕는 <b>빅데이터<\/b> 솔루션을 만나보세요."
# 		},
# 		{
# 			"title":"<b>빅 데이터<\/b>란 무엇입니까? | Oracle 대한민국",
# 			"link":"https:\/\/www.oracle.com\/kr\/big-data\/what-is-big-data\/",
# 			"description":"<b>빅데이터<\/b>는 특히 새로운 <b>데이터<\/b> 소스에서 나온 더 크고 더 복잡한 <b>데이터<\/b> 세트입니다. <b>빅데이터<\/b>의 이점, 과제 및 모범 사례 외에도 정의 및 역사에 대해 알아보세요."
# 		},
# 		{
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
df = pd.read_json(response_body.decode('utf-8'))
df['items']
# Out:
# 0     {'title': '<b>빅 데이터</b> 프로세싱 - 나무위키', 'link': ...
# 1     {'title': '<b>빅데이터</b>란? | 고급 <b>빅데이터</b> 분석 |...
# 2     {'title': '<b>빅 데이터</b>란 무엇입니까? | Oracle 대한민국'...
# 3     {'title': '<b>빅데이터</b>(big data) 이해 - 정의, 분석, ...
# 4     {'title': '네이버 <b>데이터</b>랩', 'link': 'https://...
# 5     {'title': '<b>빅데이터</b> - BC카드', 'link': 'https...
# 6     {'title': '트라이빅 소개 &lt; 서비스 안내 : KOTRA 무역투자<b>...
# 7     {'title': '국가기술 <b>빅데이터</b> 분석기사 - <b>데이터</b>자...
# 8     {'title': '<b>빅데이터</b>의 이해 - 글이 작품이 되는 공간, 브런치...
# 9     {'title': '미디어백과: <b>빅데이터</b> - 네이버 지식백과', 'li...
# 10    {'title': '<b>빅 데이터</b> 분석 솔루션 | HPE 대한민국', 'l...
# 11    {'title': '한눈에 보는 민원 <b>빅데이터</b>', 'link': 'ht...
# 12    {'title': '<b>빅데이터</b> - 비투엔', 'link': 'http:/...
# 13    {'title': '<b>빅 데이터</b> - 반도체 기술 및 응용 | 삼성반도체'...
# 14    {'title': '<b>빅데이터</b> 취업 | 직업별 채용정보 - 사람인', '...
# 15    {'title': '<b>빅데이터</b> - 백석대학교', 'link': 'http...
# 16    {'title': '<b>빅데이터</b> 분석자료&lt;<b>빅데이터</b>&lt;...
# ...

# %% [markdown]
# #### 과제 0728_2
# 뉴스, 영화, 쇼핑, 지식in, 카페글에서 적합한 주제에 대한 데이터를 가져와서 데이터프레임으로 출력하세요

# %%
import os
import sys
from urllib import request
import pandas as pd
import urllib

# https://openapi.naver.com/v1/search/cafearticle.json
client_id = "NlyY4vYvuvzxx0l7vhB8"
client_secret = "0mDeMw5Q0v"
encText = urllib.parse.quote(input('질의 검색:'))
url = "https://openapi.naver.com/v1/search/cafearticle.json?query="+encText+"&display=20&start=1" #json 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode ==200):
    response_body1 = response.read()
    print(response_body1.decode('utf-8'))
else:
    print("Erro code:"+rescode)
# Out:
# 질의 검색:장고
# {
# 	"lastBuildDate":"Fri, 29 Jul 2022 09:25:32 +0900",
# 	"total":108844,
# 	"start":1,
# 	"display":20,
# 	"items":[
# 		{
# 			"title":"와인<b>장고<\/b>",
# 			"link":"http:\/\/cafe.naver.com\/winerack24\/184867",
# 			"description":"LG8구 셀러 쓰다가 큰 녀석으로 사고 싶은데 형편이 안되네유ㅜ 그래서 와쌉 지난글에 타이머로 온도조절하신분 글참고해서 저도 저만의 와인<b>장고<\/b> 마련했는데 이마저도 만실이네요.. 이젠 재대로 된 셀러 마련해야할까봐요",
# 			"cafename":"★와쌉★ 와인 싸게 사는 사람들",
# 			"cafeurl":"https:\/\/cafe.naver.com\/winerack24"
# 		},
# 		{
# 			"title":"핫토이 스타워즈 <b>장고<\/b>펫이 왔습니다~^^",
# 			"link":"http:\/\/cafe.naver.com\/actionfigure\/1644253",
# 			"description":"스타워즈 피규어 입문전에 제품이라 예약을 못해 직구로 구입한 <b>장고<\/b>펫 입니다. 사이드쇼 <b>장고<\/b>펫도 소장해 봤지만 역시 최신 <b>장고<\/b>펫이라 그런지 안정감이나 퀄리티등등 너무 좋네요. 운좋게 토요일에 받아 간단 소장기... ",
# 			"cafename":"액션피겨 (액션피규어)",
# 			"cafeurl":"https:\/\/cafe.naver.com\/actionfigure"
# 		},
# 		{
# 			"title":"<b>장고<\/b>(abs) vs 니키 고민중 도와주세요",
# 			"link":"http:\/\/cafe.naver.com\/bikecargogo\/5003930",
# ...

# %%
import pandas as pd
df_j = pd.read_json(response_body1.decode('utf-8'))
df_j['items']

titli = []
linkli = []
des = []
for i in range(20):
    for key,value in df_j.iloc[i,1].items():
        if key == 'title':
            titli.append(value)
        elif key == 'link':
            linkli.append(value)
        else :
            des.append(value)
df_j2 = pd.DataFrame(zip(titli,linkli,des),columns=['title','link','description'])
# df_j2.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [36], in <cell line: 8>()
#       7 des = []
#       8 for i in range(20):
# ----> 9     for key,value in df_j.iloc[i,1].items():
#      10         if key == 'title':
#      11             titli.append(value)
#
# AttributeError: 'numpy.int64' object has no attribute 'items'

# %%
import os
import sys
import urllib.request
client_id = "NlyY4vYvuvzxx0l7vhB8"
client_secret = "0mDeMw5Q0v"
encText = urllib.parse.quote('빅데이터')
cot = str(input('최소10 최대100\n'))
stpage = str(input('최소1 최대 1000\n'))
url = "https://openapi.naver.com/v1/search/webkr.xml?query="+ encText + '&display='+cot+'&start='+stpage
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    html = response_body.decode('utf-8')
    xml = pd.read_xml(html,xpath='.//item')
else:
    print("Error Code:" + rescode)

# %% [markdown]
# #### 과제0728_3 아래사항에 유의하여 OpenWeatherMap 날씨정보를 웹 API로 가져와서 출력하세요
# * https://openweathermap.org/api 사이트에서 Current Weather data에 대한 API doc 내용을 파악
# * 개발자 등록을 하고 API 키 발급 받음(https://home.openweathermap.org/users/sign_up)
# * New Account 등록 후 API Keys라는 탭에서 API Key 확인 가능
# * 기본적으로 유료 사이트이지만 현재 날씨, 5일까지의 날씨는 무료로 사용할 수 있음(단 1분에 60번만 호출 가능)
# * 서울, 토쿄, 뉴욕의 날씨를 가져오는 프로그램 작성(text로 가져와서 json으로 변환하여 일차 출력)
#   - cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
#   - 가져올 정보 : 도시별 날씨(description), 최저 기온(temp_min), 최고 기온(temp_max), 습도(humidity), 기압(pressure), 풍속(speed)
#   - 기온 데이터는 켈빈 온도로 되어 있으며 섭씨 온도로 변환해서 출력
# * json 포멧으로 출력 데이터를 아래와 같이 가독력 있게 출력(소수점 2번째에서 반올림 처리)

# %% [markdown]
# """
# + 도시 = Seoul
# | 날씨 = broken clouds
# | 최저 기온 = -1.0 2
# | 최고 기온 = 2.0 2
# | 습도 = 74
# | 기압 = 1023
# | 풍속 = 0.5
# """

# %%
https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}
AIPkey = 9a13387bf016bab6439ff271a621df5a

# %% [markdown]
# ## 공공데이터 api

# %% [markdown]
# #### 상가 업소정보

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json

skey = 'xzdFSUzXm0ymcDjr13BCz5jPE2cH1oXyvkni%2B%2F0keg5o27HHhyCLqhiPewn%2Fg9hQIr0rmfFLDwOY0tTXWUXBHg%3D%3D'
res_id = 'storezone'
stype = 'json'

# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=storezone&key=9144&ServiceKey=서비스인증키


url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
params = f'?ServiceKey={skey}&type={stype}&resId={res_id}&'+urlencode({quote_plus('key'):'9174'})
# params ={'serviceKey' : '서비스키', 'key' : '9174', 'type' : 'xml' }
query = url + params
print(query)

request = Request(query)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
print(response_body)

response_dict = json.loads(response_body.decode('utf-8'))
items = response_dict['body']['items']

df = pd.DataFrame(items)
df

# response = requests.get(url, params=params)
# print(response.content)
# Out:
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?ServiceKey=xzdFSUzXm0ymcDjr13BCz5jPE2cH1oXyvkni%2B%2F0keg5o27HHhyCLqhiPewn%2Fg9hQIr0rmfFLDwOY0tTXWUXBHg%3D%3D&type=json&resId=storezone&key=9174
# ...

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
import pandas as pd
import json

def baro_api(skey,res_id,encode):
    
    stype = 'json'
    url = 'http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi'
    params = f'?serviceKey={skey}&type={stype}&resId={res_id}&'+ encode
    query = url + params
    
    request = Request(query)
    request.get_method = lambda: 'GET'
    response_body = urlopen(request).read()
    
    response_dict = json.loads(response_body.decode('utf-8'))
    items = response_dict['body']['items']
    df = pd.DataFrame(items)
    return df

# %% [markdown]
# ## 상권조회

# %% [markdown]
# ### 지정 상권조회

# %%
skey = 'xzdFSUzXm0ymcDjr13BCz5jPE2cH1oXyvkni%2B%2F0keg5o27HHhyCLqhiPewn%2Fg9hQIr0rmfFLDwOY0tTXWUXBHg%3D%3D'
res_id = 'storezone'
encode = urlencode({quote_plus('key'):'9193'})

baro_api(skey,res_id, encode)
# Out:
#    trarNo  mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9193  동대문역사문화공원역       11    서울특별시    11140       중구     79167        17
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.00304244009 37.56673071604...  2021-06-30

# %% [markdown]
# ### 반경내 상권조회

# %%
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=storezone&catId=radius&radius=500&cx=127.004528&cy=37.567538&ServiceKey=서비스인증키

res_id ='storezone'
encode = urlencode({quote_plus('catId'):'radius',quote_plus('radius'):'500',
                   quote_plus('cx'):'127.004528',quote_plus('cy'):'37.567538'})

baro_api(skey,res_id, encode)
# Out:
#    trarNo  mainTrarNm ctprvnCd ctprvnNm signguCd signguNm  trarArea  coordNum  \
# 0    9170     동대문시장_1       11    서울특별시    11110      종로구     75046        13
# 1    9180     종로5가역_1       11    서울특별시    11110      종로구     44881         9
# 2    9192     동대문시장_2       11    서울특별시    11140       중구     60995        18
# 3    9193  동대문역사문화공원역       11    서울특별시    11140       중구     79167        17
# 4    9206      을지로4가역       11    서울특별시    11140       중구     81565         9
#
#                                               coords      stdrDt
# 0  MULTIPOLYGON (((127.00616674831 37.57097429301...  2021-06-30
# 1  MULTIPOLYGON (((127.001579474423 37.5708212220...  2021-06-30
# 2  MULTIPOLYGON (((127.006693001676 37.5694470928...  2021-06-30
# 3  MULTIPOLYGON (((127.00304244009 37.56673071604...  2021-06-30
# 4  MULTIPOLYGON (((126.998050690253 37.5686092455...  2021-06-30

# %% [markdown]
# #### 과제0728_4 사각형내 상권조회

# %% [markdown]
# ### 행정단위 상권조회

# %% [markdown]
# ### 상가업소 조회

# %% [markdown]
# ### 행정동 단위 상가업소 조회

# %%
# http://apis.data.go.kr/B553077/api/open/sdsc2/baroApi?resId=store&catId=dong&divId=ctprvnCd&key=11&ServiceKey=서비스인증키
skey = 'xzdFSUzXm0ymcDjr13BCz5jPE2cH1oXyvkni%2B%2F0keg5o27HHhyCLqhiPewn%2Fg9hQIr0rmfFLDwOY0tTXWUXBHg%3D%3D'
res_id = 'store'
encode = urlencode({quote_plus('catId'):'dong',quote_plus('divId'):'ctprvnCd',quote_plus('key'):'11'})
baro_api(skey, res_id, encode)
# Out:
#      bizesId     bizesNm  brchNm indsLclsCd indsLclsNm indsMclsCd  \
# 0   10001387      이음스튜디오                  D         소매        D18
# 1   10004623      이철헤어커커    상계역점          F      생활서비스        F01
# 2   10016187        일조산업                  D         소매        D07
# 3   10030788      장안순대국밥                  Q         음식        Q10
# 4   10031349         장어야    동자동점          Q         음식        Q01
# 5   10031436        장어천국                  Q         음식        Q01
# 6   10034303        재건공조                  D         소매        D07
# 7   10034977        재진패션                  D         소매        D05
# 8   10038561   전자랜드프라이스킹     은평점          D         소매        D12
# 9   10041487         정관장   서대문역점          D         소매        D03
# 10  10041503         정관장   남부법원점          D         소매        D10
# 11  10050747       제시카키친  이대하늬솔점          Q         음식        Q06
# 12  10056742      제일전기조명                  D         소매        D07
# ...
